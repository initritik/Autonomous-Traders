# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 220px; height: 150px; vertical-align: middle;">
#             <img src="../assets/aaa.png" width="220" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Autonomous Traders</h2>
#             <span style="color:#ff7800;">An equity trading simulation to illustrate autonomous agents powered by tools and resources from MCP servers.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Week 6 Day 4
#
# Welcome to the Capstone project!
#
# # Autonomous Traders
#
# An equity trading simulation with four Traders and a Researcher, powered by a team of MCP servers and their tools and resources:
#
# 1. Our home-made Accounts server, written by our engineering team
# 2. Push notifications, to alert us when something happens
# 3. Market data, for live or simulated share prices
# 4. Fetch, to read a web page through a local headless browser
# 5. Tavily, for web search
# 6. Memory, a knowledge graph the researcher writes to and reads back
#
# Plus resources to read each trader's account and their investment strategy.
#
# The whole system already lives in the `backend` package. Today we tour the key pieces, build and run a single trader to watch it work, then bring up a dashboard to see the full team trading.

# %% [markdown]
# ## The architecture
#
# Here is how the pieces fit together. Each of the four traders is an agent with its own MCP servers for accounts, push notifications and market data, and it calls a researcher agent as a tool. The researcher is itself an agent, with its own MCP servers for fetching pages, web search and memory. Orange is an agent, blue is an MCP server, and there are six MCP servers in all.
#
# While I've given the Agents names like "Trader" and "Researcher", my motivation for this architecture was managing the context effectively with the right prompts and tools for reliable outcomes. It's key to avoid the trap of assigning Agent responsibilities just because that's how human teams are organized..
#
# <img src="../assets/architecture.png" width="820" />

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">One more time --</h2>
#             <span style="color:#ff7800;">Please do not use this for actual trading decisions!!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
from dotenv import load_dotenv
import json
from contextlib import AsyncExitStack
from agents import Runner, trace, add_trace_processor
from IPython.display import Markdown, display
from backend.market import get_share_price
from backend.accounts import Account
from backend.accounts_client import read_accounts_resource
from backend.reset import reset_traders
from backend.mcp_servers import trader_mcp_servers, researcher_mcp_servers
from backend.traders import get_researcher, get_researcher_tool, Trader
from backend.tracers import LogTracer

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### A quick note for Windows
#
# Launching a local MCP server from a notebook hits one rough edge on Windows. The server writes its startup output to stderr, but inside a Windows Jupyter kernel that stream has no real file handle behind it, so the launch fails with an `io.UnsupportedOperation: fileno` error, while Mac and Linux are unaffected.
#
# The fix is to send the server's stderr to the null device, so it always has somewhere real to write. We do that once in the next cell, which lets every MCP server below start cleanly. On Mac and Linux it costs nothing beyond keeping the server's startup banner out of the notebook.

# %%
# On Windows, a stdio MCP server started from a Jupyter kernel writes to a stderr stream with no
# real file descriptor and crashes with io.UnsupportedOperation: fileno. We send the server's
# stderr to the null device so it always has somewhere real to write. Mac and Linux are unaffected.
import functools
import subprocess
import agents.mcp.server

agents.mcp.server.stdio_client = functools.partial(agents.mcp.server.stdio_client, errlog=subprocess.DEVNULL)

# %% [markdown]
# ## A tour of the backend
#
# The trading floor is already built as a Python package in `backend`. Before we run it, let's look at a few of the pieces it gives us.

# %% [markdown]
# ### Market data
#
# `get_share_price` returns the latest price for a symbol. With a Massive API key it uses live market data; without one it falls back to a simulator, so the floor runs either way.

# %%
get_share_price("AAPL")
# Out:
# 324.96

# %% [markdown]
# ### The traders' accounts
#
# Each trader has an account: a balance, holdings, a transaction history and an investment strategy. The `Account` model is the heart of our home-made Accounts server. Let's reset the four traders to their starting strategies and look at one of them.
#
# #### Ed note:
#
# I have commented out the first line because I don't want to reset my traders!

# %%
# reset_traders() 
warren = Account.get("Warren")
print("Balance:", warren.balance)
print("Strategy:", warren.get_strategy())
# Out:
# Balance: 10000.0
# Strategy:

# %% [markdown]
# ### The MCP servers, and their tools
#
# The trader and the researcher each get their own set of MCP servers, and `mcp_servers.py` builds them for us. Let's start each one and count the tools they expose.

# %%
servers = trader_mcp_servers() + researcher_mcp_servers("Warren")
count = 0
for server in servers:
    async with server:
        tools = await server.list_tools()
        count += len(tools)
print(f"We have {len(servers)} MCP servers, and {count} tools")
# Out:
# ---------------------------------------------------------------------------
# McpError                                  Traceback (most recent call last)
# Cell In[6], line 4
#       1 servers = trader_mcp_servers() + researcher_mcp_servers("Warren")
#       2 count = 0
#       3 for server in servers:
# ----> 4     async with server:
#       5         tools = await server.list_tools()
#       6         count += len(tools)
#       7 print(f"We have {len(servers)} MCP servers, and {count} tools")
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\.venv\Lib\site-packages\agents\mcp\server.py:653, in _MCPServerWithClientSession.__aenter__(self)
#     652 async def __aenter__(self):
# --> 653     await self.connect()
#     654     return self
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\.venv\Lib\site-packages\agents\mcp\server.py:726, in _MCPServerWithClientSession.connect(self)
#     714 self._get_session_id = rest[0] if rest and callable(rest[0]) else None
#     716 session = await self.exit_stack.enter_async_context(
#     717     ClientSession(
#     718         read,
#    (...)    724     )
#     725 )
# --> 726 server_result = await session.initialize()
#     727 self.server_initialize_result = server_result
#     728 self.session = session
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\.venv\Lib\site-packages\mcp\client\session.py:171, in ClientSession.initialize(self)
#     154 elicitation = (
#     155     types.ElicitationCapability(
#     156         form=types.FormElicitationCapability(),
#    (...)    160     else None
#     161 )
#     162 roots = (
#     163     # TODO: Should this be based on whether we
#     164     # _will_ send notifications, or only whether
#    (...)    168     else None
#     169 )
# --> 171 result = await self.send_request(
#     172     types.ClientRequest(
#     173         types.InitializeRequest(
#     174             params=types.InitializeRequestParams(
#     175                 protocolVersion=types.LATEST_PROTOCOL_VERSION,
#     176                 capabilities=types.ClientCapabilities(
#     177                     sampling=sampling,
#     178                     elicitation=elicitation,
#     179                     experimental=None,
#     180                     roots=roots,
#     181                     tasks=self._task_handlers.build_capability(),
#     182                 ),
#     183                 clientInfo=self._client_info,
#     184             ),
#     185         )
#     186     ),
#     187     types.InitializeResult,
#     188 )
#     190 if result.protocolVersion not in SUPPORTED_PROTOCOL_VERSIONS:
#     191     raise RuntimeError(f"Unsupported protocol version from the server: {result.protocolVersion}")
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\.venv\Lib\site-packages\mcp\shared\session.py:306, in BaseSession.send_request(self, request, result_type, request_read_timeout_seconds, metadata, progress_callback)
#     294     raise McpError(
#     295         ErrorData(
#     296             code=httpx.codes.REQUEST_TIMEOUT,
#    (...)    302         )
#     303     )
#     305 if isinstance(response_or_error, JSONRPCError):
# --> 306     raise McpError(response_or_error.error)
#     307 else:
#     308     return result_type.model_validate(response_or_error.result)
#
# McpError: Connection closed

# %% [markdown]
# ## The Researcher
#
# The trader does not search the web itself. Instead it calls a Researcher agent as one of its tools. The researcher has its own MCP servers: Fetch to read pages, Tavily for web search, and a Memory it writes to and reads back.
#
# Tavily offers several tools, from plain search to a heavyweight deep-research mode. We restrict its server to `tavily_search`, which keeps the researcher fast and focused. Choosing which tools an agent can see is itself context engineering.
#
# Wrapping an agent as a tool is different from a handoff: with a tool the trader stays in control and gets the researcher's answer back, where a handoff would pass the whole conversation over.

# %%
async with AsyncExitStack() as stack:
    servers = [await stack.enter_async_context(server) for server in researcher_mcp_servers("Warren")]
    researcher = await get_researcher(servers, "gpt-5.4-mini")
    with trace("Researcher"):
        result = await Runner.run(researcher, "What's the latest news on Amazon?", max_turns=30)
display(Markdown(result.final_output))
# Out:
# Error getting response: Error code: 429 - {'error': {'message': 'You have no credits remaining. Add credits to continue using the API at https://platform.openai.com/settings/organization/billing/.', 'type': 'insufficient_quota', 'param': None, 'code': 'credit_balance_exhausted'}}. (request_id: req_2a5edbacfac34ff19bded367ae50f608)
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[7], line 5
#       1 async with AsyncExitStack() as stack:
#       2     servers = [await stack.enter_async_context(server) for server in researcher_mcp_servers("Warren")]
#       3     researcher = await get_researcher(servers, "gpt-5.4-mini")
#       4     with trace("Researcher"):
# ----> 5         result = await Runner.run(researcher, "What's the latest news on Amazon?", max_turns=30)
#       6 display(Markdown(result.final_output))
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\.venv\Lib\site-packages\agents\run.py:260, in Runner.run(cls, starting_agent, input, context, max_turns, hooks, run_config, error_handlers, previous_response_id, auto_previous_response_id, conversation_id, session)
#     210 """
#     211 Run a workflow starting at the given agent.
#     212
#    (...)    256     type of the output.
#     257 """
#     259 runner = DEFAULT_AGENT_RUNNER
# --> 260 return await runner.run(
#     261     starting_agent,
#     262     input,
#     263     context=context,
#     264     max_turns=max_turns,
#     265     hooks=hooks,
#     266     run_config=run_config,
#     267     error_handlers=error_handlers,
#     268     previous_response_id=previous_response_id,
#     269     auto_previous_response_id=auto_previous_response_id,
#     270     conversation_id=conversation_id,
#     271     session=session,
#     272 )
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\.venv\Lib\site-packages\agents\run.py:1231, in AgentRunner.run(self, starting_agent, input, **kwargs)
#    1229         raise
#    1230 else:
# -> 1231     turn_result = await model_task
#    1233 input_guardrail_results.extend(sequential_results)
#    1234 input_guardrail_results.extend(parallel_results)
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\.venv\Lib\site-packages\agents\run_internal\run_loop.py:1753, in run_single_turn(bindings, all_tools, original_input, generated_items, hooks, context_wrapper, run_config, should_run_agent_start_hooks, tool_use_tracker, server_conversation_tracker, session, session_items_to_rewind, reasoning_item_id_policy, prompt_cache_key_resolver, error_handlers)
#    1750 else:
#    1751     input = _prepare_turn_input_items(original_input, generated_items, reasoning_item_id_policy)
# -> 1753 new_response = await get_new_response(
#    1754     bindings,
#    1755     system_prompt,
#    1756     input,
#    1757     output_schema,
#    1758     all_tools,
#    1759     handoffs,
#    1760     hooks,
#    1761     context_wrapper,
#    1762     run_config,
#    1763     tool_use_tracker,
#    1764     server_conversation_tracker,
#    1765     prompt_config,
#    1766     session=session,
#    1767     session_items_to_rewind=session_items_to_rewind,
#    1768     prompt_cache_key_resolver=prompt_cache_key_resolver,
#    1769 )
#    1771 return await get_single_step_result_from_response(
#    1772     bindings=bindings,
#    1773     original_input=original_input,
#    (...)   1784     server_manages_conversation=server_conversation_tracker is not None,
#    1785 )
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\.venv\Lib\site-packages\agents\run_internal\run_loop.py:1872, in get_new_response(bindings, system_prompt, input, output_schema, all_tools, handoffs, hooks, context_wrapper, run_config, tool_use_tracker, server_conversation_tracker, prompt_config, session, session_items_to_rewind, prompt_cache_key_resolver)
#    1869     if server_conversation_tracker is not None:
#    1870         server_conversation_tracker.rewind_input(filtered.input)
# -> 1872 new_response = await get_response_with_retry(
#    1873     get_response=lambda: model.get_response(
#    1874         system_instructions=filtered.instructions,
#    1875         input=filtered.input,
#    1876         model_settings=model_settings,
#    1877         tools=all_tools,
#    1878         output_schema=output_schema,
#    1879         handoffs=handoffs,
#    1880         tracing=get_model_tracing_impl(
#    1881             run_config.tracing_disabled, run_config.trace_include_sensitive_data
#    1882         ),
#    1883         previous_response_id=previous_response_id,
#    1884         conversation_id=conversation_id,
#    1885         prompt=prompt_config,
#    1886     ),
#    1887     rewind=rewind_model_request,
#    1888     retry_settings=model_settings.retry,
#    1889     get_retry_advice=model.get_retry_advice,
#    1890     previous_response_id=previous_response_id,
#    1891     conversation_id=conversation_id,
#    1892 )
#    1893 if server_conversation_tracker is not None:
#    1894     # Retry helpers rewind sent-input tracking before replaying a failed request. Mark the
#    1895     # filtered input as delivered again once a retry succeeds so subsequent turns only send
#    1896     # new deltas.
#    1897     server_conversation_tracker.mark_input_as_sent(filtered.input)
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\.venv\Lib\site-packages\agents\run_internal\model_retry.py:544, in get_response_with_retry(get_response, rewind, retry_settings, get_retry_advice, previous_response_id, conversation_id)
#     531 try:
#     532     # Keep provider retries on the initial attempt, but disable them on explicit
#     533     # no-retry settings and on any replay attempt that the runner manages itself.
#     534     with (
#     535         provider_managed_retries_disabled(
#     536             _should_disable_provider_managed_retries(
#    (...)    542         websocket_pre_event_retries_disabled(disable_websocket_pre_event_retry),
#     543     ):
# --> 544         response = await get_response()
#     545     response.usage = apply_retry_attempt_usage(
#     546         response.usage,
#     547         failed_policy_attempts + compatibility_retries_taken,
#     548     )
#     549     return response
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\.venv\Lib\site-packages\agents\models\openai_responses.py:461, in OpenAIResponsesModel.get_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, tracing, previous_response_id, conversation_id, prompt)
#     459 with response_span(disabled=tracing.is_disabled()) as span_response:
#     460     try:
# --> 461         response = await self._fetch_response(
#     462             system_instructions,
#     463             input,
#     464             model_settings,
#     465             tools,
#     466             output_schema,
#     467             handoffs,
#     468             previous_response_id=previous_response_id,
#     469             conversation_id=conversation_id,
#     470             stream=False,
#     471             prompt=prompt,
#     472         )
#     474         if _debug.DONT_LOG_MODEL_DATA:
#     475             logger.debug("LLM responded")
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\.venv\Lib\site-packages\agents\models\openai_responses.py:681, in OpenAIResponsesModel._fetch_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, previous_response_id, conversation_id, stream, prompt)
#     678 client = self._get_client()
#     680 if not stream:
# --> 681     response = await client.responses.create(**create_kwargs)
#     682     return cast(Response, response)
#     684 streaming_response = getattr(client.responses, "with_streaming_response", None)
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\.venv\Lib\site-packages\openai\resources\responses\responses.py:2616, in AsyncResponses.create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#    2577 async def create(
#    2578     self,
#    2579     *,
#    (...)   2614     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    2615 ) -> Response | AsyncStream[ResponseStreamEvent]:
# -> 2616     return await self._post(
#    2617         "/responses",
#    2618         body=await async_maybe_transform(
#    2619             {
#    2620                 "background": background,
#    2621                 "context_management": context_management,
#    2622                 "conversation": conversation,
#    2623                 "include": include,
#    2624                 "input": input,
#    2625                 "instructions": instructions,
#    2626                 "max_output_tokens": max_output_tokens,
#    2627                 "max_tool_calls": max_tool_calls,
#    2628                 "metadata": metadata,
#    2629                 "model": model,
#    2630                 "parallel_tool_calls": parallel_tool_calls,
#    2631                 "previous_response_id": previous_response_id,
#    2632                 "prompt": prompt,
#    2633                 "prompt_cache_key": prompt_cache_key,
#    2634                 "prompt_cache_retention": prompt_cache_retention,
#    2635                 "reasoning": reasoning,
#    2636                 "safety_identifier": safety_identifier,
#    2637                 "service_tier": service_tier,
#    2638                 "store": store,
#    2639                 "stream": stream,
#    2640                 "stream_options": stream_options,
#    2641                 "temperature": temperature,
#    2642                 "text": text,
#    2643                 "tool_choice": tool_choice,
#    2644                 "tools": tools,
#    2645                 "top_logprobs": top_logprobs,
#    2646                 "top_p": top_p,
#    2647                 "truncation": truncation,
#    2648                 "user": user,
#    2649             },
#    2650             response_create_params.ResponseCreateParamsStreaming
#    2651             if stream
#    2652             else response_create_params.ResponseCreateParamsNonStreaming,
#    2653         ),
#    2654         options=make_request_options(
#    2655             extra_headers=extra_headers,
#    2656             extra_query=extra_query,
#    2657             extra_body=extra_body,
#    2658             timeout=timeout,
#    2659             security={"bearer_auth": True},
#    2660         ),
#    2661         cast_to=Response,
#    2662         stream=stream or False,
#    2663         stream_cls=AsyncStream[ResponseStreamEvent],
#    2664     )
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\.venv\Lib\site-packages\openai\_base_client.py:1931, in AsyncAPIClient.post(self, path, cast_to, body, content, files, options, stream, stream_cls)
#    1922     warnings.warn(
#    1923         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1924         "Please pass raw bytes via the `content` parameter instead.",
#    1925         DeprecationWarning,
#    1926         stacklevel=2,
#    1927     )
#    1928 opts = FinalRequestOptions.construct(
#    1929     method="post", url=path, json_data=body, content=content, files=await async_to_httpx_files(files), **options
#    1930 )
# -> 1931 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\.venv\Lib\site-packages\openai\_base_client.py:1716, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1713             await err.response.aread()
#    1715         log.debug("Re-raising status error")
# -> 1716         raise self._make_status_error_from_response(err.response) from None
#    1718     break
#    1720 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You have no credits remaining. Add credits to continue using the API at https://platform.openai.com/settings/organization/billing/.', 'type': 'insufficient_quota', 'param': None, 'code': 'credit_balance_exhausted'}}

# %% [markdown]
# ### Look at the trace
#
# https://platform.openai.com/traces

# %% [markdown]
# ### Wrapping the researcher as a tool
#
# The trader does not talk to the researcher directly. We turn the whole researcher agent into a tool, and the trader calls it like any other tool. `get_researcher_tool` does this with `researcher.as_tool(...)`.

# %%
researcher_tool = await get_researcher_tool(researcher_mcp_servers("Warren"), "gpt-5.4-mini")
print("Tool name:", researcher_tool.name)
print("Description:", researcher_tool.description)

# %% [markdown]
# ## The Trader
#
# The `Trader` class in `traders.py` brings it together. It builds the researcher as a tool, creates the trader agent over the trader's MCP servers (accounts, push and market data) with that tool, and runs it against a message built from the trader's strategy and current account.
#
# There is one more piece worth seeing. The OpenAI Agents SDK lets you plug into its tracing, so you can follow what each agent does in code. `tracers.py` has a custom trace processor that records each trader's steps to the database, which is how we surface their thinking on the dashboard. We register it now, then run Warren.

# %%
add_trace_processor(LogTracer())
warren = Trader("Warren", "Patience", "gpt-5.4-mini")
await warren.run()
# Out:
# ---------------------------------------------------------------------------
# WouldBlock                                Traceback (most recent call last)
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\.venv\Lib\site-packages\anyio\streams\memory.py:117, in MemoryObjectReceiveStream.receive(self)
#     116 try:
# --> 117     return self.receive_nowait()
#     118 except WouldBlock:
#     119     # Add ourselves in the queue
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\.venv\Lib\site-packages\anyio\streams\memory.py:112, in MemoryObjectReceiveStream.receive_nowait(self)
#     110     raise EndOfStream
# --> 112 raise WouldBlock
#
# WouldBlock:
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 add_trace_processor(LogTracer())
#       2 warren = Trader("Warren", "Patience", "gpt-5.4-mini")
# ----> 3 await warren.run()
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\6_mcp\backend\traders.py:121, in Trader.run(self)
#     119 async def run(self):
#     120     try:
# --> 121         await self.run_with_trace()
#     122     except Exception as e:
#     123         print(f"Error running trader {self.name}: {e}")
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\6_mcp\backend\traders.py:117, in Trader.run_with_trace(self)
#     115 trace_id = make_trace_id(f"{self.name.lower()}")
#     116 with trace(trace_name, trace_id=trace_id):
# --> 117     await self.run_with_mcp_servers()
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\6_mcp\backend\traders.py:105, in Trader.run_with_mcp_servers(self)
#     102 async def run_with_mcp_servers(self):
#     103     async with AsyncExitStack() as stack:
#     104         trader_servers = [
# --> 105             await stack.enter_async_context(server) for server in trader_mcp_servers()
#     106         ]
#     107         researcher_servers = [
#     108             await stack.enter_async_context(server)
#     109             for server in researcher_mcp_servers(self.name)
#     110         ]
#     111         await self.run_agent(trader_servers, researcher_servers)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\Lib\contextlib.py:659, in AsyncExitStack.enter_async_context(self, cm)
#     655 except AttributeError:
#     656     raise TypeError(f"'{cls.__module__}.{cls.__qualname__}' object does "
#     657                     f"not support the asynchronous context manager protocol"
#     658                    ) from None
# --> 659 result = await _enter(cm)
#     660 self._push_async_cm_exit(cm, _exit)
#     661 return result
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\.venv\Lib\site-packages\agents\mcp\server.py:653, in _MCPServerWithClientSession.__aenter__(self)
#     652 async def __aenter__(self):
# --> 653     await self.connect()
#     654     return self
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\.venv\Lib\site-packages\agents\mcp\server.py:726, in _MCPServerWithClientSession.connect(self)
#     714 self._get_session_id = rest[0] if rest and callable(rest[0]) else None
#     716 session = await self.exit_stack.enter_async_context(
#     717     ClientSession(
#     718         read,
#    (...)    724     )
#     725 )
# --> 726 server_result = await session.initialize()
#     727 self.server_initialize_result = server_result
#     728 self.session = session
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\.venv\Lib\site-packages\mcp\client\session.py:171, in ClientSession.initialize(self)
#     154 elicitation = (
#     155     types.ElicitationCapability(
#     156         form=types.FormElicitationCapability(),
#    (...)    160     else None
#     161 )
#     162 roots = (
#     163     # TODO: Should this be based on whether we
#     164     # _will_ send notifications, or only whether
#    (...)    168     else None
#     169 )
# --> 171 result = await self.send_request(
#     172     types.ClientRequest(
#     173         types.InitializeRequest(
#     174             params=types.InitializeRequestParams(
#     175                 protocolVersion=types.LATEST_PROTOCOL_VERSION,
#     176                 capabilities=types.ClientCapabilities(
#     177                     sampling=sampling,
#     178                     elicitation=elicitation,
#     179                     experimental=None,
#     180                     roots=roots,
#     181                     tasks=self._task_handlers.build_capability(),
#     182                 ),
#     183                 clientInfo=self._client_info,
#     184             ),
#     185         )
#     186     ),
#     187     types.InitializeResult,
#     188 )
#     190 if result.protocolVersion not in SUPPORTED_PROTOCOL_VERSIONS:
#     191     raise RuntimeError(f"Unsupported protocol version from the server: {result.protocolVersion}")
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\.venv\Lib\site-packages\mcp\shared\session.py:292, in BaseSession.send_request(self, request, result_type, request_read_timeout_seconds, metadata, progress_callback)
#     290 try:
#     291     with anyio.fail_after(timeout):
# --> 292         response_or_error = await response_stream_reader.receive()
#     293 except TimeoutError:
#     294     raise McpError(
#     295         ErrorData(
#     296             code=httpx.codes.REQUEST_TIMEOUT,
#    (...)    302         )
#     303     )
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\.venv\Lib\site-packages\anyio\streams\memory.py:125, in MemoryObjectReceiveStream.receive(self)
#     122 self._state.waiting_receivers[receive_event] = receiver
#     124 try:
# --> 125     await receive_event.wait()
#     126 finally:
#     127     self._state.waiting_receivers.pop(receive_event, None)
#
# File c:\Users\Ritik Roushan\Desktop\KEC\Graduated\Gen AI Development\AI Engineer Agentic Track\Agentic AI Projects\Capstone Project\.venv\Lib\site-packages\anyio\_backends\_asyncio.py:1804, in Event.wait(self)
#    1802     await AsyncIOBackend.checkpoint()
#    1803 else:
# -> 1804     await self._event.wait()
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.12-windows-x86_64-none\Lib\asyncio\locks.py:212, in Event.wait(self)
#     210 self._waiters.append(fut)
#     211 try:
# --> 212     await fut
#     213     return True
#     214 finally:
#
# CancelledError:

# %% [markdown]
# ### How did Warren do?
#
# Reading the account back through its MCP resource shows the trades Warren made and the state of the portfolio.

# %%
resources = await read_accounts_resource("Warren")
info = json.loads(resources)
print(info["transactions"][-1])

# %% [markdown]
# ## The whole team, on a loop
#
# `trading_floor.py` is the full backend implementation. It creates all four traders and runs them on a timer:
#
# ```
# while True:
#     await asyncio.gather(*[trader.run() for trader in traders])
#     await asyncio.sleep(RUN_EVERY_N_MINUTES * 60)
# ```
#
# A few optional settings in your `.env` file control it:
#
# `RUN_EVERY_N_MINUTES=60` sets how often the team runs, defaulting to every 60 minutes.
#
# `RUN_EVEN_WHEN_MARKET_IS_CLOSED=False` decides whether the traders run out of hours.
#
# `USE_MANY_MODELS=False` runs all four traders on gpt-5.4-mini by default. Set it to true to give each trader a different model: GPT-5.5, DeepSeek V4, Gemini 3.5 Flash and Grok 4.3.

# %% [markdown]
# ## The dashboard
#
# Now let's watch it. The dashboard lives in the `demo` package, and `app.py` launches it.
#
# Open a new terminal (the plus on the terminal panel), change to this directory and run the dashboard:
#
# `cd 6_mcp`
#
# `uv run app.py`
#
# Then, to set the team trading, open another terminal, change to the same directory and start the engine:
#
# `cd 6_mcp`
#
# `uv run -m backend.trading_floor`
#
# Watch the dashboard, and see your trading team in action.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Keep an eye on your API usage</h2>
#             <span style="color:#ff7800;">The engine runs on a loop, every hour or however you set it. Watch your API usage and stop it when you have seen enough. I find myself watching this happily for hours, and I hope you will too.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Almost there
#
# You have an autonomous trading floor: four traders, a researcher, six MCP servers, persistent memory and a live dashboard.
#
# In the final lab we give it a production frontend, a separate web app that talks to the same backend.
